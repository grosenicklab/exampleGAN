# %% [markdown]
# ## vanilla GAN by Goodfellow et al., 2014
# ##### directories that belong with this JN = MNIST and runs

# %% [markdown]
# ##### https://www.machinecurve.com/index.php/2021/07/17/building-a-simple-vanilla-gan-with-pytorch/

# %%
#Imports

import os
import torch
from torch import nn
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from torchvision import transforms
import numpy as np
import matplotlib.pyplot as plt
import uuid

# %%
#Configurable variables 

num_epochs = 50
noise_dimension = 50
batch_size = 128
train_on_gpu = True
unique_run_id = str(uuid.uuid4())
stats_after_batch = 50
optimizer_lr = 0.0002
optimizer_betas = (0.5, 0.999)
generator_output_img_shape = 28*28*1 #784

# %%
#Speed ups; makes the code run faster

torch.autograd.set_detect_anomaly(False)
torch.autograd.profiler.profile(False)
torch.autograd.profiler.emit_nvtx(False)
torch.backends.cudnn.benchmark = True

# %%
#Generator 

class Generator(nn.Module):
    '''
    vanilla GAN generator 
    '''
    def __init__(self,):
        super().__init__()
        self.layers = nn.Sequential(
        #1st upsampling
        nn.Linear(noise_dimension, 128, bias=False),
        nn.BatchNorm1d(128, 0.8),
        nn.LeakyReLU(0.25),
        #2nd upsampling
        nn.Linear(128, 256, bias=False),
        nn.BatchNorm1d(256, 0.8),
        nn.LeakyReLU(0.25),
        #3rd upsampling
        nn.Linear(256, 512, bias=False),
        nn.BatchNorm1d(512, 0.8),
        nn.LeakyReLU(0.25),
        #Final upsampling
        nn.Linear(512, generator_output_img_shape, bias=False),
        nn.Tanh()
    )
    
    def forward(self, x):
        '''Forward pass'''
        return self.layers(x)

# %%
#Discriminator

class Discriminator(nn.Module):
    '''
    vanilla GAN discriminator
    '''
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(generator_output_img_shape, 1024),
            nn.LeakyReLU(0.25),
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.25),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.25),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )
    
    def forward(self, x):
        '''Forward pass'''
        return self.layers(x)

# %%
#Housekeeping functions (device, directory creation, image generation, saving models, printing training progress)

def get_device():
    '''Gets device based on settings and availability'''
    return torch.device("cuda:0" if torch.cuda.is_available() and train_on_gpu else "cpu")

def make_directory_for_run():
    """ Make a directory for this training run. """
    print(f'Preparing training run {unique_run_id}')
    if not os.path.exists('./runs'):
        os.mkdir('./runs')
    os.mkdir(f'./runs/{unique_run_id}')

def generate_image(generator, epoch = 0, batch = 0, device=get_device()):
    """ Generate subplots with generated examples. """
    images = []
    noise = generate_noise(batch_size, device=device)
    generator.eval()
    images = generator(noise)
    plt.figure(figsize=(10, 10))
    for i in range(16):
    # Get image
        image = images[i]
    # Convert image back onto CPU and reshape
        image = image.cpu().detach().numpy()
        image = np.reshape(image, (28, 28))
    # Plot
        plt.subplot(4, 4, i+1)
        plt.imshow(image, cmap='gray')
        plt.axis('off')
    if not os.path.exists(f'./runs/{unique_run_id}/images'):
        os.mkdir(f'./runs/{unique_run_id}/images')
    print(f'./runs/{unique_run_id}/images/epoch{epoch}_batch{batch}.jpg') 
    plt.savefig(f'./runs/{unique_run_id}/images/epoch{epoch}_batch{batch}.jpg')

def save_models(generator, discriminator, epoch):
    """ Save models at specific point in time. """
    torch.save(generator.state_dict(), f'./runs/{unique_run_id}/generator_{epoch}.pth')
    torch.save(discriminator.state_dict(), f'./runs/{unique_run_id}/discriminator_{epoch}.pth')
    
def print_training_progress(batch, generator_loss, discriminator_loss):
    """ Print training progress. """
    print('Losses after mini-batch %5d: generator %e, discriminator %e' % (batch, generator_loss, discriminator_loss))

# %%
#Forwards and backwards pass

def generate_noise(number_of_images = 1, noise_dimension = noise_dimension, device=None):
    """ Generate noise for number_of_images images, with a specific noise_dimension """
    return torch.randn(number_of_images, noise_dimension, device=device)


def efficient_zero_grad(model):
    """ 
    Apply zero_grad more efficiently
    Source: https://betterprogramming.pub/how-to-make-your-pytorch-code-run-faster-93079f3c1f7b
    """
    for param in model.parameters():
        param.grad = None

        
def forward_and_backward(model, data, loss_function, targets):
    """
    Perform forward and backward pass in a generic way. Returns loss value.
    """
    outputs = model(data)
    error = loss_function(outputs, targets)
    error.backward()
    return error.item()

# %%
#Preparing dataset

def prepare_dataset():
    """ Prepare dataset through DataLoader """
  # Prepare MNIST dataset
    dataset = MNIST(os.getcwd(), download=True, train=True, transform=transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
  ]))
    
  # Batch and shuffle data with DataLoader
    trainloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
    print("here's the trainloader:", trainloader)
  # Return dataset through DataLoader
    return trainloader

# %%
#Initialization functions (models, loss and optimizers)

def initialize_models(device = get_device()):
    """ Initialize Generator and Discriminator models """
    generator = Generator()
    discriminator = Discriminator()
  # Move models to specific device
    generator.to(device)
    discriminator.to(device)
  # Return models
    return generator, discriminator

def initialize_loss():
    """ Initialize loss function. """
    return nn.BCELoss()

def initialize_optimizers(generator, discriminator):
    """ Initialize optimizers for Generator and Discriminator. """
    generator_optimizer = torch.optim.AdamW(generator.parameters(), lr=optimizer_lr,betas=optimizer_betas)
    discriminator_optimizer = torch.optim.AdamW(discriminator.parameters(), lr=optimizer_lr,betas=optimizer_betas)
    return generator_optimizer, discriminator_optimizer

# %%
#Training step

def perform_train_step(generator, discriminator, real_data, loss_function, generator_optimizer, discriminator_optimizer, device = get_device()):
    """ Perform a single training step. """
  
  ## 1. PREPARATION = Set real and fake labels.
    real_label, fake_label = 1.0, 0.0
  # Get images on CPU or GPU as configured and available
  # Also set 'actual batch size', whih can be smaller than BATCH_SIZE in some cases.
    real_images = real_data[0].to(device)
    actual_batch_size = real_images.size(0)
    label = torch.full((actual_batch_size, 1), real_label, device=device)
    
  ## 2. TRAINING THE DISCRIMINATOR = Zero the gradients for discriminator
    efficient_zero_grad(discriminator)
  # Forward + backward on real images, reshaped
    real_images = real_images.view(real_images.size(0), -1)
    error_real_images = forward_and_backward(discriminator, real_images, loss_function, label)
  # Forward + backward on generated images
    noise = generate_noise(actual_batch_size, device=device)
    generated_images = generator(noise)
    label.fill_(fake_label)
    error_generated_images =forward_and_backward(discriminator, generated_images.detach(), loss_function, label)
  # Optim for discriminator
    discriminator_optimizer.step()
  
  ## 3. TRAINING THE GENERATOR = Forward + backward + optim for generator, including zero grad
    efficient_zero_grad(generator)
    label.fill_(real_label)
    error_generator = forward_and_backward(discriminator, generated_images, loss_function, label)
    generator_optimizer.step()
  
  ## 4. COMPUTING RESULTS = Compute loss values in floats for discriminator, which is joint loss.
    error_discriminator = error_real_images + error_generated_images
  # Return generator and discriminator loss so that it can be printed.

    return error_generator, error_discriminator

# %%
#Perform epoch

def perform_epoch(dataloader, generator, discriminator, loss_function, generator_optimizer, discriminator_optimizer, epoch):
    """ Perform a single epoch. """
    for batch_no, real_data in enumerate(dataloader, 0):
        #print(batch_no, real_data)
        # Perform training step
        generator_loss_val, discriminator_loss_val = perform_train_step(generator, discriminator, real_data, loss_function, generator_optimizer, discriminator_optimizer)
        # Print statistics and generate image after every n-th batch
        if batch_no % stats_after_batch == 0:
            #print(batch_no)
            print_training_progress(batch_no, generator_loss_val, discriminator_loss_val)
            generate_image(generator, epoch, batch_no)
        
    # Save models on epoch completion.
    save_models(generator, discriminator, epoch)
    # Clear memory after every epoch
    torch.cuda.empty_cache()

# %%
#Training

def train_dcgan():
    """ Train the DCGAN. """
  # Make directory for unique run
    make_directory_for_run()
  # Set fixed random number seed
    torch.manual_seed(42)
  # Get prepared dataset
    dataloader = prepare_dataset()
  # Initialize models
    generator, discriminator = initialize_models()
  # Initialize loss and optimizers
    loss_function = initialize_loss()
    generator_optimizer, discriminator_optimizer = initialize_optimizers(generator, discriminator)
  # Train the model
    for epoch in range(num_epochs):
        print(f'Starting epoch {epoch}...')
        perform_epoch(dataloader, generator, discriminator, loss_function, generator_optimizer, discriminator_optimizer, epoch)
  # Finished :-)
        print(f'Finished unique run {unique_run_id}')

    return dataloader, generator, discriminator, loss_function, generator_optimizer, discriminator_optimizer, epoch


if __name__ == '__main__':
    train_dcgan()
# Out:
# Preparing training run b399a87f-5687-4308-84f4-0315b43879e3
# here's the trainloader: <torch.utils.data.dataloader.DataLoader object at 0x7f0cc78bbaf0>
# Starting epoch 0...
# /home/stp4007/.conda/envs/ccganpytorch-new/lib/python3.9/site-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:189.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# /home/stp4007/.conda/envs/ccganpytorch-new/lib/python3.9/site-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Losses after mini-batch     0: generator 6.745229e-01, discriminator 1.373596e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch0_batch0.jpg
# Losses after mini-batch    50: generator 1.022229e+00, discriminator 7.818463e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch0_batch50.jpg
# Losses after mini-batch   100: generator 1.340540e+00, discriminator 7.294370e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch0_batch100.jpg
# Losses after mini-batch   150: generator 1.868642e+00, discriminator 3.538273e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch0_batch150.jpg
# Losses after mini-batch   200: generator 1.749190e+00, discriminator 2.577002e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch0_batch200.jpg
# Losses after mini-batch   250: generator 2.210368e+00, discriminator 2.003060e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch0_batch250.jpg
# Losses after mini-batch   300: generator 3.431640e+00, discriminator 1.160016e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch0_batch300.jpg
# Losses after mini-batch   350: generator 2.823534e+00, discriminator 6.969311e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch0_batch350.jpg
# Losses after mini-batch   400: generator 2.754887e+00, discriminator 2.679798e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch0_batch400.jpg
# Losses after mini-batch   450: generator 5.757617e+00, discriminator 6.663042e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch0_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 1...
# Losses after mini-batch     0: generator 3.013600e+00, discriminator 5.691632e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch1_batch0.jpg
# Losses after mini-batch    50: generator 2.046835e+00, discriminator 2.888162e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch1_batch50.jpg
# Losses after mini-batch   100: generator 2.370476e+00, discriminator 3.070990e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch1_batch100.jpg
# Losses after mini-batch   150: generator 4.919929e+00, discriminator 9.200692e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch1_batch150.jpg
# Losses after mini-batch   200: generator 1.023412e+01, discriminator 2.146269e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch1_batch200.jpg
# Losses after mini-batch   250: generator 5.301657e+00, discriminator 2.483820e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch1_batch250.jpg
# Losses after mini-batch   300: generator 3.329512e+00, discriminator 9.377095e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch1_batch300.jpg
# Losses after mini-batch   350: generator 4.057885e+00, discriminator 6.042456e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch1_batch350.jpg
# Losses after mini-batch   400: generator 1.993326e+00, discriminator 4.484264e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch1_batch400.jpg
# Losses after mini-batch   450: generator 4.110995e+00, discriminator 3.027150e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch1_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 2...
# Losses after mini-batch     0: generator 3.778833e+00, discriminator 2.032111e-01
# <ipython-input-6-2b3e4760038c>:20: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10, 10))
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch2_batch0.jpg
# Losses after mini-batch    50: generator 3.868990e+00, discriminator 3.352023e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch2_batch50.jpg
# Losses after mini-batch   100: generator 5.883999e+00, discriminator 4.193586e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch2_batch100.jpg
# Losses after mini-batch   150: generator 1.293555e+00, discriminator 1.094400e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch2_batch150.jpg
# Losses after mini-batch   200: generator 3.763147e+00, discriminator 1.695218e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch2_batch200.jpg
# Losses after mini-batch   250: generator 3.015695e+00, discriminator 2.875500e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch2_batch250.jpg
# Losses after mini-batch   300: generator 4.048510e+00, discriminator 8.717086e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch2_batch300.jpg
# Losses after mini-batch   350: generator 5.242754e+00, discriminator 1.509096e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch2_batch350.jpg
# Losses after mini-batch   400: generator 6.259218e+00, discriminator 1.863763e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch2_batch400.jpg
# Losses after mini-batch   450: generator 3.855747e+00, discriminator 3.226669e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch2_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 3...
# Losses after mini-batch     0: generator 3.429371e+00, discriminator 1.714060e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch3_batch0.jpg
# Losses after mini-batch    50: generator 5.927915e+00, discriminator 3.726666e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch3_batch50.jpg
# Losses after mini-batch   100: generator 3.248392e+00, discriminator 2.309503e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch3_batch100.jpg
# Losses after mini-batch   150: generator 5.642403e+00, discriminator 2.784276e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch3_batch150.jpg
# Losses after mini-batch   200: generator 3.606179e+00, discriminator 2.185023e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch3_batch200.jpg
# Losses after mini-batch   250: generator 3.103785e+00, discriminator 2.393599e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch3_batch250.jpg
# Losses after mini-batch   300: generator 3.123424e+00, discriminator 1.863446e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch3_batch300.jpg
# Losses after mini-batch   350: generator 3.318603e+00, discriminator 2.275735e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch3_batch350.jpg
# Losses after mini-batch   400: generator 4.229426e+00, discriminator 1.449473e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch3_batch400.jpg
# Losses after mini-batch   450: generator 4.646940e+00, discriminator 3.854899e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch3_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 4...
# Losses after mini-batch     0: generator 9.601698e+00, discriminator 1.108451e-01
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch4_batch0.jpg
# Losses after mini-batch    50: generator 6.154237e+00, discriminator 1.609856e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch4_batch50.jpg
# Losses after mini-batch   100: generator 5.404972e+00, discriminator 3.205761e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch4_batch100.jpg
# Losses after mini-batch   150: generator 5.979302e+00, discriminator 5.977339e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch4_batch150.jpg
# Losses after mini-batch   200: generator 6.695703e+00, discriminator 2.356944e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch4_batch200.jpg
# Losses after mini-batch   250: generator 7.659304e+00, discriminator 6.208993e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch4_batch250.jpg
# Losses after mini-batch   300: generator 8.343666e+00, discriminator 1.621918e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch4_batch300.jpg
# Losses after mini-batch   350: generator 2.397536e+01, discriminator 2.735000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch4_batch350.jpg
# Losses after mini-batch   400: generator 4.819463e+00, discriminator 4.641810e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch4_batch400.jpg
# Losses after mini-batch   450: generator 5.638885e+00, discriminator 4.323283e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch4_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 5...
# Losses after mini-batch     0: generator 4.848610e+00, discriminator 4.133851e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch5_batch0.jpg
# Losses after mini-batch    50: generator 6.428586e+00, discriminator 8.690414e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch5_batch50.jpg
# Losses after mini-batch   100: generator 7.497409e+00, discriminator 1.392342e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch5_batch100.jpg
# Losses after mini-batch   150: generator 7.625745e+00, discriminator 1.100557e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch5_batch150.jpg
# Losses after mini-batch   200: generator 7.666656e+00, discriminator 1.426034e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch5_batch200.jpg
# Losses after mini-batch   250: generator 7.507156e+00, discriminator 8.843194e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch5_batch250.jpg
# Losses after mini-batch   300: generator 6.250181e+00, discriminator 4.168951e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch5_batch300.jpg
# Losses after mini-batch   350: generator 7.710136e+00, discriminator 7.636108e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch5_batch350.jpg
# Losses after mini-batch   400: generator 8.617860e+00, discriminator 7.506436e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch5_batch400.jpg
# Losses after mini-batch   450: generator 6.294754e+00, discriminator 2.245404e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch5_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 6...
# Losses after mini-batch     0: generator 9.610097e+00, discriminator 7.087371e-05
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch6_batch0.jpg
# Losses after mini-batch    50: generator 6.472972e+00, discriminator 3.581537e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch6_batch50.jpg
# Losses after mini-batch   100: generator 5.407977e+00, discriminator 9.673066e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch6_batch100.jpg
# Losses after mini-batch   150: generator 5.958375e+00, discriminator 1.121185e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch6_batch150.jpg
# Losses after mini-batch   200: generator 6.632496e+00, discriminator 2.597100e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch6_batch200.jpg
# Losses after mini-batch   250: generator 6.354849e+00, discriminator 2.979249e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch6_batch250.jpg
# Losses after mini-batch   300: generator 7.310724e+00, discriminator 1.526088e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch6_batch300.jpg
# Losses after mini-batch   350: generator 8.157169e+00, discriminator 3.172634e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch6_batch350.jpg
# Losses after mini-batch   400: generator 8.364384e+00, discriminator 3.996292e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch6_batch400.jpg
# Losses after mini-batch   450: generator 8.237286e+00, discriminator 1.268699e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch6_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 7...
# Losses after mini-batch     0: generator 6.733594e+00, discriminator 6.346557e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch7_batch0.jpg
# Losses after mini-batch    50: generator 7.771588e+00, discriminator 5.291170e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch7_batch50.jpg
# Losses after mini-batch   100: generator 8.146698e+00, discriminator 5.683464e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch7_batch100.jpg
# Losses after mini-batch   150: generator 7.897901e+00, discriminator 5.094180e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch7_batch150.jpg
# Losses after mini-batch   200: generator 8.744087e+00, discriminator 2.077926e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch7_batch200.jpg
# Losses after mini-batch   250: generator 7.862618e+00, discriminator 5.755322e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch7_batch250.jpg
# Losses after mini-batch   300: generator 8.238668e+00, discriminator 3.393485e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch7_batch300.jpg
# Losses after mini-batch   350: generator 8.913774e+00, discriminator 1.500907e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch7_batch350.jpg
# Losses after mini-batch   400: generator 8.927755e+00, discriminator 1.592738e-04
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch7_batch400.jpg
# Losses after mini-batch   450: generator 2.177174e+01, discriminator 6.998223e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch7_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 8...
# Losses after mini-batch     0: generator 1.521710e+01, discriminator 8.912631e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch8_batch0.jpg
# Losses after mini-batch    50: generator 5.449162e+00, discriminator 3.912617e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch8_batch50.jpg
# Losses after mini-batch   100: generator 5.588296e+00, discriminator 1.415513e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch8_batch100.jpg
# Losses after mini-batch   150: generator 4.770025e+00, discriminator 3.000051e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch8_batch150.jpg
# Losses after mini-batch   200: generator 5.406018e+00, discriminator 1.172638e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch8_batch200.jpg
# Losses after mini-batch   250: generator 4.994990e+00, discriminator 3.487939e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch8_batch250.jpg
# Losses after mini-batch   300: generator 6.294215e+00, discriminator 6.131473e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch8_batch300.jpg
# Losses after mini-batch   350: generator 4.471615e+00, discriminator 2.667245e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch8_batch350.jpg
# Losses after mini-batch   400: generator 5.376340e+00, discriminator 3.329121e-02
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch8_batch400.jpg
# Losses after mini-batch   450: generator 6.776428e+00, discriminator 3.225547e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch8_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 9...
# Losses after mini-batch     0: generator 6.599206e+00, discriminator 3.541415e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch9_batch0.jpg
# Losses after mini-batch    50: generator 7.921711e+00, discriminator 1.719894e-03
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch9_batch50.jpg
# Losses after mini-batch   100: generator 3.348341e+01, discriminator 7.922717e-05
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch9_batch100.jpg
# Losses after mini-batch   150: generator 9.880681e+01, discriminator 3.818491e-07
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch9_batch150.jpg
# Losses after mini-batch   200: generator 9.799649e+01, discriminator 5.587938e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch9_batch200.jpg
# Losses after mini-batch   250: generator 9.812221e+01, discriminator 3.725291e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch9_batch250.jpg
# Losses after mini-batch   300: generator 9.744836e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch9_batch300.jpg
# Losses after mini-batch   350: generator 9.763763e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch9_batch350.jpg
# Losses after mini-batch   400: generator 9.707731e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch9_batch400.jpg
# Losses after mini-batch   450: generator 9.764885e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch9_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 10...
# Losses after mini-batch     0: generator 9.809550e+01, discriminator 4.377225e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch10_batch0.jpg
# Losses after mini-batch    50: generator 9.775273e+01, discriminator 3.725291e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch10_batch50.jpg
# Losses after mini-batch   100: generator 9.833832e+01, discriminator 2.747450e-07
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch10_batch100.jpg
# Losses after mini-batch   150: generator 9.753557e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch10_batch150.jpg
# Losses after mini-batch   200: generator 9.705988e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch10_batch200.jpg
# Losses after mini-batch   250: generator 9.743929e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch10_batch250.jpg
# Losses after mini-batch   300: generator 9.798757e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch10_batch300.jpg
# Losses after mini-batch   350: generator 9.759062e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch10_batch350.jpg
# Losses after mini-batch   400: generator 9.628518e+01, discriminator 2.468044e-07
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch10_batch400.jpg
# Losses after mini-batch   450: generator 9.718217e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch10_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 11...
# Losses after mini-batch     0: generator 9.665767e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch11_batch0.jpg
# Losses after mini-batch    50: generator 9.802903e+01, discriminator 1.583249e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch11_batch50.jpg
# Losses after mini-batch   100: generator 9.741111e+01, discriminator 2.142044e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch11_batch100.jpg
# Losses after mini-batch   150: generator 9.745004e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch11_batch150.jpg
# Losses after mini-batch   200: generator 9.569764e+01, discriminator 5.587938e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch11_batch200.jpg
# Losses after mini-batch   250: generator 9.747598e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch11_batch250.jpg
# Losses after mini-batch   300: generator 9.632350e+01, discriminator 5.587937e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch11_batch300.jpg
# Losses after mini-batch   350: generator 9.776868e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch11_batch350.jpg
# Losses after mini-batch   400: generator 9.689717e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch11_batch400.jpg
# Losses after mini-batch   450: generator 9.739999e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch11_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 12...
# Losses after mini-batch     0: generator 9.683923e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch12_batch0.jpg
# Losses after mini-batch    50: generator 9.792497e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch12_batch50.jpg
# Losses after mini-batch   100: generator 9.737341e+01, discriminator 6.519261e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch12_batch100.jpg
# Losses after mini-batch   150: generator 9.751172e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch12_batch150.jpg
# Losses after mini-batch   200: generator 9.648856e+01, discriminator 7.450584e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch12_batch200.jpg
# Losses after mini-batch   250: generator 9.735541e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch12_batch250.jpg
# Losses after mini-batch   300: generator 9.729437e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch12_batch300.jpg
# Losses after mini-batch   350: generator 9.735043e+01, discriminator 4.656614e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch12_batch350.jpg
# Losses after mini-batch   400: generator 9.708273e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch12_batch400.jpg
# Losses after mini-batch   450: generator 9.676640e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch12_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 13...
# Losses after mini-batch     0: generator 9.713333e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch13_batch0.jpg
# Losses after mini-batch    50: generator 9.624515e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch13_batch50.jpg
# Losses after mini-batch   100: generator 9.611768e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch13_batch100.jpg
# Losses after mini-batch   150: generator 9.516917e+01, discriminator 8.381906e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch13_batch150.jpg
# Losses after mini-batch   200: generator 9.686156e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch13_batch200.jpg
# Losses after mini-batch   250: generator 9.744162e+01, discriminator 7.450583e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch13_batch250.jpg
# Losses after mini-batch   300: generator 9.652490e+01, discriminator 9.592681e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch13_batch300.jpg
# Losses after mini-batch   350: generator 9.685796e+01, discriminator 5.587937e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch13_batch350.jpg
# Losses after mini-batch   400: generator 9.671397e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch13_batch400.jpg
# Losses after mini-batch   450: generator 9.691043e+01, discriminator 6.426151e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch13_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 14...
# Losses after mini-batch     0: generator 9.721482e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch14_batch0.jpg
# Losses after mini-batch    50: generator 9.643557e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch14_batch50.jpg
# Losses after mini-batch   100: generator 9.592580e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch14_batch100.jpg
# Losses after mini-batch   150: generator 9.675930e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch14_batch150.jpg
# Losses after mini-batch   200: generator 9.757346e+01, discriminator 9.406386e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch14_batch200.jpg
# Losses after mini-batch   250: generator 9.737434e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch14_batch250.jpg
# Losses after mini-batch   300: generator 9.715379e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch14_batch300.jpg
# Losses after mini-batch   350: generator 9.701968e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch14_batch350.jpg
# Losses after mini-batch   400: generator 9.721320e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch14_batch400.jpg
# Losses after mini-batch   450: generator 9.676749e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch14_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 15...
# Losses after mini-batch     0: generator 9.662121e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch15_batch0.jpg
# Losses after mini-batch    50: generator 9.655499e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch15_batch50.jpg
# Losses after mini-batch   100: generator 9.678474e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch15_batch100.jpg
# Losses after mini-batch   150: generator 9.628130e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch15_batch150.jpg
# Losses after mini-batch   200: generator 9.564005e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch15_batch200.jpg
# Losses after mini-batch   250: generator 9.619118e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch15_batch250.jpg
# Losses after mini-batch   300: generator 9.616595e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch15_batch300.jpg
# Losses after mini-batch   350: generator 9.670928e+01, discriminator 2.039623e-07
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch15_batch350.jpg
# Losses after mini-batch   400: generator 9.594016e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch15_batch400.jpg
# Losses after mini-batch   450: generator 9.678067e+01, discriminator 1.583250e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch15_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 16...
# Losses after mini-batch     0: generator 9.664534e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch16_batch0.jpg
# Losses after mini-batch    50: generator 9.665424e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch16_batch50.jpg
# Losses after mini-batch   100: generator 9.578325e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch16_batch100.jpg
# Losses after mini-batch   150: generator 9.648871e+01, discriminator 3.725291e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch16_batch150.jpg
# Losses after mini-batch   200: generator 9.597178e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch16_batch200.jpg
# Losses after mini-batch   250: generator 9.541743e+01, discriminator 1.303853e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch16_batch250.jpg
# Losses after mini-batch   300: generator 9.601907e+01, discriminator 1.862647e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch16_batch300.jpg
# Losses after mini-batch   350: generator 9.688757e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch16_batch350.jpg
# Losses after mini-batch   400: generator 9.601579e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch16_batch400.jpg
# Losses after mini-batch   450: generator 9.640665e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch16_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 17...
# Losses after mini-batch     0: generator 9.537074e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch17_batch0.jpg
# Losses after mini-batch    50: generator 9.605634e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch17_batch50.jpg
# Losses after mini-batch   100: generator 9.625325e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch17_batch100.jpg
# Losses after mini-batch   150: generator 9.619653e+01, discriminator 3.725291e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch17_batch150.jpg
# Losses after mini-batch   200: generator 9.531386e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch17_batch200.jpg
# Losses after mini-batch   250: generator 9.593789e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch17_batch250.jpg
# Losses after mini-batch   300: generator 9.556856e+01, discriminator 4.656614e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch17_batch300.jpg
# Losses after mini-batch   350: generator 9.540221e+01, discriminator 9.313228e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch17_batch350.jpg
# Losses after mini-batch   400: generator 9.534692e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch17_batch400.jpg
# Losses after mini-batch   450: generator 9.548225e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch17_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 18...
# Losses after mini-batch     0: generator 9.516165e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch18_batch0.jpg
# Losses after mini-batch    50: generator 9.591316e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch18_batch50.jpg
# Losses after mini-batch   100: generator 9.569115e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch18_batch100.jpg
# Losses after mini-batch   150: generator 9.636832e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch18_batch150.jpg
# Losses after mini-batch   200: generator 9.568834e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch18_batch200.jpg
# Losses after mini-batch   250: generator 9.520564e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch18_batch250.jpg
# Losses after mini-batch   300: generator 9.572093e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch18_batch300.jpg
# Losses after mini-batch   350: generator 9.523412e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch18_batch350.jpg
# Losses after mini-batch   400: generator 9.508848e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch18_batch400.jpg
# Losses after mini-batch   450: generator 9.578441e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch18_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 19...
# Losses after mini-batch     0: generator 9.543336e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch19_batch0.jpg
# Losses after mini-batch    50: generator 9.572856e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch19_batch50.jpg
# Losses after mini-batch   100: generator 9.598740e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch19_batch100.jpg
# Losses after mini-batch   150: generator 9.548846e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch19_batch150.jpg
# Losses after mini-batch   200: generator 9.540799e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch19_batch200.jpg
# Losses after mini-batch   250: generator 9.564799e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch19_batch250.jpg
# Losses after mini-batch   300: generator 9.426663e+01, discriminator 3.725291e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch19_batch300.jpg
# Losses after mini-batch   350: generator 9.518742e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch19_batch350.jpg
# Losses after mini-batch   400: generator 9.432652e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch19_batch400.jpg
# Losses after mini-batch   450: generator 9.485471e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch19_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 20...
# Losses after mini-batch     0: generator 9.584241e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch20_batch0.jpg
# Losses after mini-batch    50: generator 9.520497e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch20_batch50.jpg
# Losses after mini-batch   100: generator 9.593648e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch20_batch100.jpg
# Losses after mini-batch   150: generator 9.553465e+01, discriminator 5.587938e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch20_batch150.jpg
# Losses after mini-batch   200: generator 9.541796e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch20_batch200.jpg
# Losses after mini-batch   250: generator 9.631224e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch20_batch250.jpg
# Losses after mini-batch   300: generator 9.446331e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch20_batch300.jpg
# Losses after mini-batch   350: generator 9.457542e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch20_batch350.jpg
# Losses after mini-batch   400: generator 9.501777e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch20_batch400.jpg
# Losses after mini-batch   450: generator 9.416768e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch20_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 21...
# Losses after mini-batch     0: generator 9.396507e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch21_batch0.jpg
# Losses after mini-batch    50: generator 9.445333e+01, discriminator 1.303853e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch21_batch50.jpg
# Losses after mini-batch   100: generator 9.444375e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch21_batch100.jpg
# Losses after mini-batch   150: generator 9.503262e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch21_batch150.jpg
# Losses after mini-batch   200: generator 9.450781e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch21_batch200.jpg
# Losses after mini-batch   250: generator 9.358385e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch21_batch250.jpg
# Losses after mini-batch   300: generator 9.343502e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch21_batch300.jpg
# Losses after mini-batch   350: generator 9.521548e+01, discriminator 6.519260e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch21_batch350.jpg
# Losses after mini-batch   400: generator 9.462651e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch21_batch400.jpg
# Losses after mini-batch   450: generator 9.479828e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch21_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 22...
# Losses after mini-batch     0: generator 9.434540e+01, discriminator 1.955780e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch22_batch0.jpg
# Losses after mini-batch    50: generator 9.427766e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch22_batch50.jpg
# Losses after mini-batch   100: generator 9.414526e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch22_batch100.jpg
# Losses after mini-batch   150: generator 9.490394e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch22_batch150.jpg
# Losses after mini-batch   200: generator 9.388535e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch22_batch200.jpg
# Losses after mini-batch   250: generator 9.472607e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch22_batch250.jpg
# Losses after mini-batch   300: generator 9.423638e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch22_batch300.jpg
# Losses after mini-batch   350: generator 9.381102e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch22_batch350.jpg
# Losses after mini-batch   400: generator 9.435673e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch22_batch400.jpg
# Losses after mini-batch   450: generator 9.418637e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch22_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 23...
# Losses after mini-batch     0: generator 9.247968e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch23_batch0.jpg
# Losses after mini-batch    50: generator 9.341071e+01, discriminator 3.818431e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch23_batch50.jpg
# Losses after mini-batch   100: generator 9.291887e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch23_batch100.jpg
# Losses after mini-batch   150: generator 9.514771e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch23_batch150.jpg
# Losses after mini-batch   200: generator 9.313791e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch23_batch200.jpg
# Losses after mini-batch   250: generator 9.405724e+01, discriminator 1.303852e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch23_batch250.jpg
# Losses after mini-batch   300: generator 9.304125e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch23_batch300.jpg
# Losses after mini-batch   350: generator 9.346704e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch23_batch350.jpg
# Losses after mini-batch   400: generator 9.387234e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch23_batch400.jpg
# Losses after mini-batch   450: generator 9.265208e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch23_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 24...
# Losses after mini-batch     0: generator 9.231793e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch24_batch0.jpg
# Losses after mini-batch    50: generator 9.349102e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch24_batch50.jpg
# Losses after mini-batch   100: generator 9.231094e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch24_batch100.jpg
# Losses after mini-batch   150: generator 9.366155e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch24_batch150.jpg
# Losses after mini-batch   200: generator 9.367629e+01, discriminator 6.146752e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch24_batch200.jpg
# Losses after mini-batch   250: generator 9.247578e+01, discriminator 5.587938e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch24_batch250.jpg
# Losses after mini-batch   300: generator 9.272081e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch24_batch300.jpg
# Losses after mini-batch   350: generator 9.226207e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch24_batch350.jpg
# Losses after mini-batch   400: generator 9.247090e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch24_batch400.jpg
# Losses after mini-batch   450: generator 9.218625e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch24_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 25...
# Losses after mini-batch     0: generator 9.241182e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch25_batch0.jpg
# Losses after mini-batch    50: generator 9.281531e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch25_batch50.jpg
# Losses after mini-batch   100: generator 9.156986e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch25_batch100.jpg
# Losses after mini-batch   150: generator 9.337407e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch25_batch150.jpg
# Losses after mini-batch   200: generator 9.403032e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch25_batch200.jpg
# Losses after mini-batch   250: generator 9.400274e+01, discriminator 7.450583e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch25_batch250.jpg
# Losses after mini-batch   300: generator 9.366773e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch25_batch300.jpg
# Losses after mini-batch   350: generator 9.297626e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch25_batch350.jpg
# Losses after mini-batch   400: generator 9.195219e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch25_batch400.jpg
# Losses after mini-batch   450: generator 9.127499e+01, discriminator 1.909234e-07
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch25_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 26...
# Losses after mini-batch     0: generator 9.254514e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch26_batch0.jpg
# Losses after mini-batch    50: generator 9.295667e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch26_batch50.jpg
# Losses after mini-batch   100: generator 9.256384e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch26_batch100.jpg
# Losses after mini-batch   150: generator 9.268143e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch26_batch150.jpg
# Losses after mini-batch   200: generator 9.257751e+01, discriminator 1.583250e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch26_batch200.jpg
# Losses after mini-batch   250: generator 9.279831e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch26_batch250.jpg
# Losses after mini-batch   300: generator 9.214783e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch26_batch300.jpg
# Losses after mini-batch   350: generator 9.120109e+01, discriminator 1.024455e-08
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch26_batch350.jpg
# Losses after mini-batch   400: generator 9.291715e+01, discriminator 8.381906e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch26_batch400.jpg
# Losses after mini-batch   450: generator 9.311099e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch26_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 27...
# Losses after mini-batch     0: generator 9.206993e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch27_batch0.jpg
# Losses after mini-batch    50: generator 9.151822e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch27_batch50.jpg
# Losses after mini-batch   100: generator 9.151503e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch27_batch100.jpg
# Losses after mini-batch   150: generator 9.234528e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch27_batch150.jpg
# Losses after mini-batch   200: generator 9.218329e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch27_batch200.jpg
# Losses after mini-batch   250: generator 9.234343e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch27_batch250.jpg
# Losses after mini-batch   300: generator 9.247182e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch27_batch300.jpg
# Losses after mini-batch   350: generator 9.225139e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch27_batch350.jpg
# Losses after mini-batch   400: generator 9.168546e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch27_batch400.jpg
# Losses after mini-batch   450: generator 9.098173e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch27_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 28...
# Losses after mini-batch     0: generator 9.172800e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch28_batch0.jpg
# Losses after mini-batch    50: generator 9.208077e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch28_batch50.jpg
# Losses after mini-batch   100: generator 9.176519e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch28_batch100.jpg
# Losses after mini-batch   150: generator 9.225597e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch28_batch150.jpg
# Losses after mini-batch   200: generator 9.148639e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch28_batch200.jpg
# Losses after mini-batch   250: generator 9.019670e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch28_batch250.jpg
# Losses after mini-batch   300: generator 9.130547e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch28_batch300.jpg
# Losses after mini-batch   350: generator 9.207805e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch28_batch350.jpg
# ...
# Losses after mini-batch    50: generator 8.612803e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch40_batch50.jpg
# Losses after mini-batch   100: generator 8.609227e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch40_batch100.jpg
# Losses after mini-batch   150: generator 8.678544e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch40_batch150.jpg
# Losses after mini-batch   200: generator 8.633459e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch40_batch200.jpg
# Losses after mini-batch   250: generator 8.594724e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch40_batch250.jpg
# Losses after mini-batch   300: generator 8.561246e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch40_batch300.jpg
# Losses after mini-batch   350: generator 8.569711e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch40_batch350.jpg
# Losses after mini-batch   400: generator 8.668147e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch40_batch400.jpg
# Losses after mini-batch   450: generator 8.471008e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch40_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 41...
# Losses after mini-batch     0: generator 8.550475e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch41_batch0.jpg
# Losses after mini-batch    50: generator 8.528343e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch41_batch50.jpg
# Losses after mini-batch   100: generator 8.654668e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch41_batch100.jpg
# Losses after mini-batch   150: generator 8.608334e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch41_batch150.jpg
# Losses after mini-batch   200: generator 8.665265e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch41_batch200.jpg
# Losses after mini-batch   250: generator 8.495131e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch41_batch250.jpg
# Losses after mini-batch   300: generator 8.505733e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch41_batch300.jpg
# Losses after mini-batch   350: generator 8.509085e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch41_batch350.jpg
# Losses after mini-batch   400: generator 8.523918e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch41_batch400.jpg
# Losses after mini-batch   450: generator 8.442248e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch41_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 42...
# Losses after mini-batch     0: generator 8.586763e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch42_batch0.jpg
# Losses after mini-batch    50: generator 8.618623e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch42_batch50.jpg
# Losses after mini-batch   100: generator 8.469043e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch42_batch100.jpg
# Losses after mini-batch   150: generator 8.525388e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch42_batch150.jpg
# Losses after mini-batch   200: generator 8.397569e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch42_batch200.jpg
# Losses after mini-batch   250: generator 8.561897e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch42_batch250.jpg
# Losses after mini-batch   300: generator 8.383560e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch42_batch300.jpg
# Losses after mini-batch   350: generator 8.572536e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch42_batch350.jpg
# Losses after mini-batch   400: generator 8.432135e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch42_batch400.jpg
# Losses after mini-batch   450: generator 8.519872e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch42_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 43...
# Losses after mini-batch     0: generator 8.485992e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch43_batch0.jpg
# Losses after mini-batch    50: generator 8.527112e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch43_batch50.jpg
# Losses after mini-batch   100: generator 8.411044e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch43_batch100.jpg
# Losses after mini-batch   150: generator 8.431489e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch43_batch150.jpg
# Losses after mini-batch   200: generator 8.467432e+01, discriminator 6.519261e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch43_batch200.jpg
# Losses after mini-batch   250: generator 8.330118e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch43_batch250.jpg
# Losses after mini-batch   300: generator 8.290055e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch43_batch300.jpg
# Losses after mini-batch   350: generator 8.292039e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch43_batch350.jpg
# Losses after mini-batch   400: generator 8.433647e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch43_batch400.jpg
# Losses after mini-batch   450: generator 8.403793e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch43_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 44...
# Losses after mini-batch     0: generator 8.333179e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch44_batch0.jpg
# Losses after mini-batch    50: generator 8.386936e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch44_batch50.jpg
# Losses after mini-batch   100: generator 8.421873e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch44_batch100.jpg
# Losses after mini-batch   150: generator 8.354018e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch44_batch150.jpg
# Losses after mini-batch   200: generator 8.388920e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch44_batch200.jpg
# Losses after mini-batch   250: generator 8.361785e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch44_batch250.jpg
# Losses after mini-batch   300: generator 8.415005e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch44_batch300.jpg
# Losses after mini-batch   350: generator 8.287584e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch44_batch350.jpg
# Losses after mini-batch   400: generator 8.344044e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch44_batch400.jpg
# Losses after mini-batch   450: generator 8.378640e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch44_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 45...
# Losses after mini-batch     0: generator 8.332869e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch45_batch0.jpg
# Losses after mini-batch    50: generator 8.295205e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch45_batch50.jpg
# Losses after mini-batch   100: generator 8.218592e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch45_batch100.jpg
# Losses after mini-batch   150: generator 8.205025e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch45_batch150.jpg
# Losses after mini-batch   200: generator 8.280661e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch45_batch200.jpg
# Losses after mini-batch   250: generator 8.323192e+01, discriminator 2.793968e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch45_batch250.jpg
# Losses after mini-batch   300: generator 8.304289e+01, discriminator 9.313227e-10
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch45_batch300.jpg
# Losses after mini-batch   350: generator 8.222597e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch45_batch350.jpg
# Losses after mini-batch   400: generator 8.283968e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch45_batch400.jpg
# Losses after mini-batch   450: generator 8.339831e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch45_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 46...
# Losses after mini-batch     0: generator 8.264557e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch46_batch0.jpg
# Losses after mini-batch    50: generator 8.299820e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch46_batch50.jpg
# Losses after mini-batch   100: generator 8.260716e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch46_batch100.jpg
# Losses after mini-batch   150: generator 8.265457e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch46_batch150.jpg
# Losses after mini-batch   200: generator 8.237397e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch46_batch200.jpg
# Losses after mini-batch   250: generator 8.179311e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch46_batch250.jpg
# Losses after mini-batch   300: generator 8.178197e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch46_batch300.jpg
# Losses after mini-batch   350: generator 8.257230e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch46_batch350.jpg
# Losses after mini-batch   400: generator 8.204525e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch46_batch400.jpg
# Losses after mini-batch   450: generator 8.178600e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch46_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 47...
# Losses after mini-batch     0: generator 8.150539e+01, discriminator 8.381908e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch47_batch0.jpg
# Losses after mini-batch    50: generator 8.212858e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch47_batch50.jpg
# Losses after mini-batch   100: generator 8.147640e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch47_batch100.jpg
# Losses after mini-batch   150: generator 8.142850e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch47_batch150.jpg
# Losses after mini-batch   200: generator 8.187794e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch47_batch200.jpg
# Losses after mini-batch   250: generator 8.205396e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch47_batch250.jpg
# Losses after mini-batch   300: generator 8.249859e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch47_batch300.jpg
# Losses after mini-batch   350: generator 8.199364e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch47_batch350.jpg
# Losses after mini-batch   400: generator 8.137334e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch47_batch400.jpg
# Losses after mini-batch   450: generator 8.149213e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch47_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 48...
# Losses after mini-batch     0: generator 8.268734e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch48_batch0.jpg
# Losses after mini-batch    50: generator 8.160139e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch48_batch50.jpg
# Losses after mini-batch   100: generator 8.132526e+01, discriminator 1.862645e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch48_batch100.jpg
# Losses after mini-batch   150: generator 8.187957e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch48_batch150.jpg
# Losses after mini-batch   200: generator 8.217827e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch48_batch200.jpg
# Losses after mini-batch   250: generator 8.129798e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch48_batch250.jpg
# Losses after mini-batch   300: generator 8.229687e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch48_batch300.jpg
# Losses after mini-batch   350: generator 8.179571e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch48_batch350.jpg
# Losses after mini-batch   400: generator 8.098032e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch48_batch400.jpg
# Losses after mini-batch   450: generator 8.151717e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch48_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3
# Starting epoch 49...
# Losses after mini-batch     0: generator 8.195656e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch49_batch0.jpg
# Losses after mini-batch    50: generator 8.180000e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch49_batch50.jpg
# Losses after mini-batch   100: generator 8.122700e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch49_batch100.jpg
# Losses after mini-batch   150: generator 8.166042e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch49_batch150.jpg
# Losses after mini-batch   200: generator 8.165343e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch49_batch200.jpg
# Losses after mini-batch   250: generator 8.139939e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch49_batch250.jpg
# Losses after mini-batch   300: generator 8.135569e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch49_batch300.jpg
# Losses after mini-batch   350: generator 8.139417e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch49_batch350.jpg
# Losses after mini-batch   400: generator 8.149077e+01, discriminator 0.000000e+00
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch49_batch400.jpg
# Losses after mini-batch   450: generator 8.156105e+01, discriminator 9.313231e-09
# ./runs/b399a87f-5687-4308-84f4-0315b43879e3/images/epoch49_batch450.jpg
# Finished unique run b399a87f-5687-4308-84f4-0315b43879e3

# %%
###Test

# dataloader = prepare_dataset()
# print(type(dataloader))
# print(enumerate(dataloader))
# for i,j in enumerate(dataloader, 0):
#     print(i,j)

# generator = Generator()
# discriminator = Discriminator()
# loss_function = initialize_loss()
# generator_optimizer, discriminator_optimizer = initialize_optimizers(generator, discriminator)

# #perform_epoch(dataloader, generator, discriminator, loss_function, generator_optimizer, discriminator_optimizer, epoch)

# %% [markdown]
# #### How to load ("see") saved models
#
# #### https://pytorch.org/tutorials/beginner/saving_loading_models.html

# %% [raw]
# model = TheModelClass(*args, **kwargs)
# model.load_state_dict(torch.load(PATH))
# model.eval()

# %%
# model = Discriminator()
# model.load_state_dict(torch.load('/home/stp4007/exampleGAN/runs/53f66de5-8c5f-4a42-a2fc-7a2a8d5094d2/discriminator_4.pth'))
# model.eval()

# %%
# model = Discriminator()
# model.load_state_dict(torch.load('/home/stp4007/exampleGAN/runs/53f66de5-8c5f-4a42-a2fc-7a2a8d5094d2/discriminator_4.pth'))
# model.eval()
